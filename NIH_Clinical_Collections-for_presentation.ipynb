# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
fileName = "NIH_Clinical_Collections_I_and_II.xls"

# %%
xl = pd.ExcelFile(fileName)

# %%
xl.sheet_names
# Out:
# ['NIH Clinical Collections I and ']

# %%
df = xl.parse('NIH Clinical Collections I and ')

# %%
df.describe()
# Out:
#        STRUCTURE_REAL_AMW   PARENT_AMW   PARENT_EMW   PUBCHEM_SID
# count          726.000000   726.000000   726.000000  7.260000e+02
# mean           365.423340   340.481050   340.126161  6.875210e+07
# std            150.342271   138.973446   138.871981  2.816413e+07
# min            102.093200   102.093200   102.042900  4.638654e+07
# 25%            273.558150   256.543075   256.361800  4.638673e+07
# 50%            343.047950   316.924950   316.577750  4.638694e+07
# 75%            424.053050   395.174375   394.824150  1.041700e+08
# max           1329.485200  1269.433200  1268.641400  1.041702e+08

# %%
df.head()
# Out:
#   NCC_SAMPLE_ID                                                ISM  \
# 0  MLS001246523               CNCC[C@H](Oc1cccc2ccccc12)c3cccs3.Cl
# 1  MLS001246524               CCCN1CCCC[C@H]1C(=O)Nc2c(C)cccc2C.Cl
# 2  MLS001246525           CC(C)(C#N)c1cc(Cn2cncn2)cc(c1)C(C)(C)C#N
# 3  MLS001246526    Nc1nc(Cl)nc2n(cnc12)[C@H]3C[C@H](O)[C@@H](CO)O3
# 4  MLS001246527  CN1[C@H]2CCC[C@@H]1C[C@@H](C2)NC(=O)c3nn(C)c4c...
#
#   NCC_STRUCTURE_ID STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 0     SMR000469136     C18H19NOS.HCl            333.8770    297.4161
# 1     SMR000469137     C17H26N2O.HCl            310.8687    274.4078
# 2     SMR000466301          C17H19N5            293.3725    293.3725
# 3     SMR000058553      C10H12ClN5O3            285.6907    285.6907
# 4     SMR000469138     C18H24N4O.HCl            348.8771    312.4162
#
#    PARENT_EMW                 SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  \
# 0    297.1187  Sequoia Research Products Ltd.             SRP05005d
# 1    274.2045  Sequoia Research Products Ltd.             SRP01307r
# 2    293.1640  Sequoia Research Products Ltd.             SRP05647a
# 3    285.0628  Sequoia Research Products Ltd.             SRP03655c
# 4    312.1950  Sequoia Research Products Ltd.             SRP02575g
#
#    PUBCHEM_SID          STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS  \
# 0     46386541              DULOXETINE HCl                      NaN
# 1     46386542             ROPIVACAINE HCl                      NaN
# 2     46386543                 ANASTROZOLE                      NaN
# 3     46386544  2-CHLORO-2'-DEOXYADENOSINE                      NaN
# 4     46386545             GRANISETRON HCl                      NaN
#
#   SUPPLIER_SAMPLE_ID
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
df.tail()
# Out:
#     NCC_SAMPLE_ID                                                ISM  \
# 721  MLS002703129                    CC(Cc1ccc(O)c(O)c1)(NN)C(=O)O.O
# 722  MLS002703133        CCC(=C(c1ccccc1)c2ccc(OCCN(C)C)cc2)c3ccccc3
# 723  MLS002703135  [O-]C1=NC(=O)CN1N=Cc2ccc(o2)c3ccc(cc3)[N+](=O)...
# 724  MLS002703137  Oc1ccc2C[C@H]3N(CC=C)CC[C@]4([C@H]5Oc1c24)[C@@...
# 725  MLS003107541              Cc1ccc(cc1)N(CC2=NCCN2)c3ccc(O)cc3.Cl
#
#     NCC_STRUCTURE_ID STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 721     SMR001566944    C10H14N2O4.H2O            244.2449    226.2296
# 722     SMR001491671          C26H29NO            371.5155    371.5155
# 723     SMR000326766     C14H9N4O5.Na+            336.2396    313.2498
# 724     SMR000058766     C19H21NO4.HCl            363.8422    327.3813
# 725     SMR001819784     C17H19N3O.HCl            317.8131    281.3522
#
#      PARENT_EMW   SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  PUBCHEM_SID  \
# 721    226.0953  LightBiologicals               MZ-3023    104170225
# 722    371.2249  LightBiologicals               MZ-3027    104170047
# 723    313.0572  LightBiologicals               MZ-3030    104170142
# 724    327.1470  LightBiologicals               MZ-3032    104170085
# 725    281.1528  LightBiologicals               MZ-3036    104170130
#
#                             STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS  \
# 721                      CARBIDOPA, 38821-49-7             WHITE POWDER
# 722                      Tamoxifen, 10540-29-1             WHITE POWDER
# 723                        DantroleneÂ Sodium,            ORANGE POWDER
# 724                    NALOXONE HYDROCHLORIDE,             WHITE POWDER
# 725  PhentolamineÂ Mono-hydrochloride, 73-05-2             WHITE POWDER
#
#     SUPPLIER_SAMPLE_ID
# 721                  .
# 722                  .
# 723                  .
# 724                  .
# 725                  .

# %%
len(df)
# Out:
# 726

# %%
df.columns
# Out:
# Index(['NCC_SAMPLE_ID', 'ISM', 'NCC_STRUCTURE_ID', 'STRUCTURE_REAL_MF',
#        'STRUCTURE_REAL_AMW', 'PARENT_AMW', 'PARENT_EMW', 'SAMPLE_SUPPLIER',
#        'SUPPLIER_STRUCTURE_ID', 'PUBCHEM_SID', 'STRUCTURE_SYNONYMS',
#        'SUPPLIER_SAMPLE_COMMENTS', 'SUPPLIER_SAMPLE_ID'],
#       dtype='object')

# %%
df.loc[2]
# Out:
# NCC_SAMPLE_ID                                           MLS001246525
# ISM                         CC(C)(C#N)c1cc(Cn2cncn2)cc(c1)C(C)(C)C#N
# NCC_STRUCTURE_ID                                        SMR000466301
# STRUCTURE_REAL_MF                                           C17H19N5
# STRUCTURE_REAL_AMW                                           293.373
# PARENT_AMW                                                   293.373
# PARENT_EMW                                                   293.164
# SAMPLE_SUPPLIER                       Sequoia Research Products Ltd.
# SUPPLIER_STRUCTURE_ID                                      SRP05647a
# PUBCHEM_SID                                                 46386543
# STRUCTURE_SYNONYMS                                       ANASTROZOLE
# SUPPLIER_SAMPLE_COMMENTS                                         NaN
# SUPPLIER_SAMPLE_ID                                               NaN
# Name: 2, dtype: object

# %%
df.loc[2:5]
# Out:
#   NCC_SAMPLE_ID                                                ISM  \
# 2  MLS001246525           CC(C)(C#N)c1cc(Cn2cncn2)cc(c1)C(C)(C)C#N
# 3  MLS001246526    Nc1nc(Cl)nc2n(cnc12)[C@H]3C[C@H](O)[C@@H](CO)O3
# 4  MLS001246527  CN1[C@H]2CCC[C@@H]1C[C@@H](C2)NC(=O)c3nn(C)c4c...
# 5  MLS001246528  C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...
#
#   NCC_STRUCTURE_ID STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 2     SMR000466301          C17H19N5            293.3725    293.3725
# 3     SMR000058553      C10H12ClN5O3            285.6907    285.6907
# 4     SMR000469138     C18H24N4O.HCl            348.8771    312.4162
# 5     SMR000112560         C27H30O16            610.5274    610.5274
#
#    PARENT_EMW                 SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  \
# 2    293.1640  Sequoia Research Products Ltd.             SRP05647a
# 3    285.0628  Sequoia Research Products Ltd.             SRP03655c
# 4    312.1950  Sequoia Research Products Ltd.             SRP02575g
# 5    610.1533  Sequoia Research Products Ltd.             SRP01350r
#
#    PUBCHEM_SID          STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS  \
# 2     46386543                 ANASTROZOLE                      NaN
# 3     46386544  2-CHLORO-2'-DEOXYADENOSINE                      NaN
# 4     46386545             GRANISETRON HCl                      NaN
# 5     46386546                       RUTIN                      NaN
#
#   SUPPLIER_SAMPLE_ID
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN

# %%
df.loc[df.NCC_SAMPLE_ID == 'MLS001246524']
# Out:
#   NCC_SAMPLE_ID                                   ISM NCC_STRUCTURE_ID  \
# 1  MLS001246524  CCCN1CCCC[C@H]1C(=O)Nc2c(C)cccc2C.Cl     SMR000469137
#
#   STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  PARENT_EMW  \
# 1     C17H26N2O.HCl            310.8687    274.4078    274.2045
#
#                   SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  PUBCHEM_SID  \
# 1  Sequoia Research Products Ltd.             SRP01307r     46386542
#
#   STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS SUPPLIER_SAMPLE_ID
# 1    ROPIVACAINE HCl                      NaN                NaN

# %%
df['ISM']
# Out:
# 0                   CNCC[C@H](Oc1cccc2ccccc12)c3cccs3.Cl
# 1                   CCCN1CCCC[C@H]1C(=O)Nc2c(C)cccc2C.Cl
# 2               CC(C)(C#N)c1cc(Cn2cncn2)cc(c1)C(C)(C)C#N
# 3        Nc1nc(Cl)nc2n(cnc12)[C@H]3C[C@H](O)[C@@H](CO)O3
# 4      CN1[C@H]2CCC[C@@H]1C[C@@H](C2)NC(=O)c3nn(C)c4c...
# 5      C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...
# 6       OC(=O)c1cc(N=Nc2ccc(cc2)S(=O)(=O)Nc3ccccn3)ccc1O
# 7      CCO/C(=C\1/C(C(=C(C)N=C1C)C(=O)OC)c2cccc(c2)[N...
# 8      CCOC(=O)C1(CCN(CCC(C#N)(c2ccccc2)c3ccccc3)CC1)...
# 9                    COC(=O)CCc1ccc(OCC(O)CNC(C)C)cc1.Cl
# 10     COc1ccccc1OCC(O)CN2CCN(CC(=O)Nc3c(C)cccc3C)CC2.Cl
# 11                   CN1C(=O)CN=C(c2ccccc2)c3cc(Cl)ccc13
# 12     COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...
# 13                              CC[C@H](N1CCCC1=O)C(=O)N
# 14                           CCCN[C@H]1CCc2nc(N)sc2C1.Cl
# 15     CC(C)(C)NC(=O)[C@H]1CC[C@H]2[C@@H]3CC[C@H]4NC(...
# 16            COc1ccc(cc1OC)C(=O)NCc2ccc(OCCN(C)C)cc2.Cl
# 17           Cc1c(CS(=O)c2nc3ccccc3[nH]2)nccc1OCC(F)(F)F
# 18                    Clc1ccc2C(=C3CCNCC3)c4ncccc4CCc2c1
# 19     CCOc1cc(CC(=O)N[C@@H](CC(C)C)c2ccccc2N3CCCCC3)...
# 20              CC(=O)OCC(=O)NCCCOc1cccc(CN2CCCCC2)c1.Cl
# 21     CCCCC1=NC2(CCCC2)C(=O)N1Cc3ccc(cc3)c4ccccc4c5n...
# 22     CN(C)C(=O)Cc1c(nc2ccc(C)cn12)c3ccc(C)cc3.OC(C(...
# 23                     Cc1ccnc2N(C3CC3)c4ncccc4C(=O)Nc12
# 24     CC1(C)C[C@@H]1C(=O)N/C(=C\CCCCSC[C@H](N)C(=O)O...
# 25     CC(C)[C@@]12O[C@H]2[C@@H]3O[C@]34[C@]5(O[C@H]5...
# 26     COCc1c(nc(C(C)C)c(/C=C/[C@@H](O)C[C@@H](O)CC(=...
# 27     CC[C@]1(O)CC[C@H]2[C@@H]3CCC4=CCCC[C@@H]4[C@H]...
# 28     CN(C)CC[C@@H](c1ccc(Br)cc1)c2ccccn2.OC(=O)/C=C...
# 29     CN(C)CC[C@@H](c1ccc(Cl)cc1)c2ccccn2.OC(=O)/C=C...
#                              ...
# 696          OC(=O)COCCN1CCN(CC1)C(c2ccccc2)c3ccc(Cl)cc3
# 697    Cc1onc(c1C(=O)N[C@H]2[C@H]3SC(C)(C)[C@@H](N3C2...
# 698      CN1/C(=C(/O)\c2ccccc2S1(=O)=O)/C(=O)Nc3ncc(C)s3
# 699    COc1cccc2C(=O)c3c(O)c4C[C@](O)(C[C@H](OC5CC(N)...
# 700                  Nc1ccn([C@@H]2CS[C@H](CO)O2)c(=O)n1
# 701     Cc1ccc(cc1)c2cc(nn2c3ccc(cc3)S(=O)(=O)N)C(F)(F)F
# 702                       NCc1ccc(cc1)S(=O)(=O)N.CC(=O)O
# 703    CN(C)S(=O)(=O)c1ccc2Sc3ccccc3\C(=C\CCN4CCNCC4)...
# 704    CON=C(C(=O)NC1C2SCC(=C(N2C1=O)C(=O)[O-])COC(=O...
# 705                       CC(C)NCC(O)COc1cccc2ccccc12.Cl
# 706                       CC1(CC2CC3(C)C1)CC(N)(C2)C3.Cl
# 707                                CNCC(O)c1ccc(O)c(O)c1
# 708    C[C@H]1C[C@H]2[C@@H]3CC[C@](O)(C(=O)COC(=O)C)[...
# 709    O[C@H]([C@H]1CCCCN1)c2cc(nc3c(cccc23)C(F)(F)F)...
# 710    CCC(=O)OCC(=O)[C@@]1(OC(=O)CC)[C@@H](C)C[C@H]2...
# 711    OCCNCCNc1ccc(NCCNCCO)c2C(=O)c3c(O)ccc(O)c3C(=O...
# 712    CCOC(=O)[C@@H](CCc1ccccc1)N[C@@H](C)C(=O)N2CCC...
# 713    CCCC1O[C@@H]2C[C@H]3[C@@H]4CCC5=CC(=O)C=C[C@]5...
# 714    CCOC(=O)[C@H](CCc1ccccc1)N[C@@H](C)C(=O)N2[C@@...
# 715                              NCC(O)c1ccc(O)c(O)c1.Cl
# 716    CC(=O)OCC(=O)C12OC3(CCCC3)OC2CC4C5CCC6=CC(=O)C...
# 717    CCN(CC)CCOc1ccc(cc1)C(=C(Cl)c2ccccc2)c3ccccc3....
# 718    CC(C)(C(=O)O)c1ccc(cc1)C(O)CCCN2CCC(CC2)C(O)(c...
# 719    CC1CC2C3CCC(O)(C(=O)C)C3(C)CC(O)C2(F)C4(C)C=CC...
# 720       CN[C@H]1CC[C@@H](c2ccc(Cl)c(Cl)c2)c3ccccc13.Cl
# 721                      CC(Cc1ccc(O)c(O)c1)(NN)C(=O)O.O
# 722          CCC(=C(c1ccccc1)c2ccc(OCCN(C)C)cc2)c3ccccc3
# 723    [O-]C1=NC(=O)CN1N=Cc2ccc(o2)c3ccc(cc3)[N+](=O)...
# 724    Oc1ccc2C[C@H]3N(CC=C)CC[C@]4([C@H]5Oc1c24)[C@@...
# 725                Cc1ccc(cc1)N(CC2=NCCN2)c3ccc(O)cc3.Cl
# Name: ISM, dtype: object

# %%
df[df.STRUCTURE_REAL_AMW > 500].count()
# Out:
# NCC_SAMPLE_ID               87
# ISM                         87
# NCC_STRUCTURE_ID            87
# STRUCTURE_REAL_MF           87
# STRUCTURE_REAL_AMW          87
# PARENT_AMW                  87
# PARENT_EMW                  87
# SAMPLE_SUPPLIER             87
# SUPPLIER_STRUCTURE_ID       87
# PUBCHEM_SID                 87
# STRUCTURE_SYNONYMS          87
# SUPPLIER_SAMPLE_COMMENTS    21
# SUPPLIER_SAMPLE_ID          21
# dtype: int64

# %%
bigDf = df[df.STRUCTURE_REAL_AMW > 600]
bigDf.head()
# Out:
#    NCC_SAMPLE_ID                                                ISM  \
# 5   MLS001246528  C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...
# 12  MLS001246538  COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...
# 32  MLS001246560  COc1ccc(cc1)c2oc3c(CC=C(C)C)c(O[C@@H]4O[C@H](C...
# 39  MLS001246568  CC[C@]1(O)C[C@H]2CN(C1)CCc3c([nH]c4ccccc34)[C@...
# 40  MLS001246570  CC[C@]1(O)C[C@@H]2CN(C1)CCc3c([nH]c4ccccc34)[C...
#
#    NCC_STRUCTURE_ID  STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 5      SMR000112560          C27H30O16            610.5274    610.5274
# 12     SMR000469280     C34H36MgN6O6S2            713.1236    713.1236
# 32     SMR000466309          C33H40O15            676.6740    676.6740
# 39     SMR000469153   C43H55N5O7.H2O4S            852.0208    753.9423
# 40     SMR000058540  C46H56N4O10.H2O4S            923.0533    824.9748
#
#     PARENT_EMW                 SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  \
# 5     610.1533  Sequoia Research Products Ltd.             SRP01350r
# 12    712.5187  Sequoia Research Products Ltd.             SRP01485e
# 32    676.2367  Sequoia Research Products Ltd.             SRP00325i
# 39    753.4101  Sequoia Research Products Ltd.             SRP01038v
# 40    824.3996  Sequoia Research Products Ltd.             SRP01037v
#
#     PUBCHEM_SID   STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS  \
# 5      46386546                RUTIN                      NaN
# 12     46386556      ESOMEPRAZOLE Mg                      NaN
# 32     46386578              ICARIIN                      NaN
# 39     46386586    VINDESINE SULFATE                      NaN
# 40     46386588  VINCRISTINE SULFATE                      NaN
#
#    SUPPLIER_SAMPLE_ID
# 5                 NaN
# 12                NaN
# 32                NaN
# 39                NaN
# 40                NaN

# %%
bigDf = bigDf.set_index('NCC_SAMPLE_ID')
bigDf.head()
# Out:
#                                                              ISM  \
# NCC_SAMPLE_ID
# MLS001246528   C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...
# MLS001246538   COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...
# MLS001246560   COc1ccc(cc1)c2oc3c(CC=C(C)C)c(O[C@@H]4O[C@H](C...
# MLS001246568   CC[C@]1(O)C[C@H]2CN(C1)CCc3c([nH]c4ccccc34)[C@...
# MLS001246570   CC[C@]1(O)C[C@@H]2CN(C1)CCc3c([nH]c4ccccc34)[C...
#
#               NCC_STRUCTURE_ID  STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  \
# NCC_SAMPLE_ID
# MLS001246528      SMR000112560          C27H30O16            610.5274
# MLS001246538      SMR000469280     C34H36MgN6O6S2            713.1236
# MLS001246560      SMR000466309          C33H40O15            676.6740
# MLS001246568      SMR000469153   C43H55N5O7.H2O4S            852.0208
# MLS001246570      SMR000058540  C46H56N4O10.H2O4S            923.0533
#
#                PARENT_AMW  PARENT_EMW                 SAMPLE_SUPPLIER  \
# NCC_SAMPLE_ID
# MLS001246528     610.5274    610.1533  Sequoia Research Products Ltd.
# MLS001246538     713.1236    712.5187  Sequoia Research Products Ltd.
# MLS001246560     676.6740    676.2367  Sequoia Research Products Ltd.
# MLS001246568     753.9423    753.4101  Sequoia Research Products Ltd.
# MLS001246570     824.9748    824.3996  Sequoia Research Products Ltd.
#
#               SUPPLIER_STRUCTURE_ID  PUBCHEM_SID   STRUCTURE_SYNONYMS  \
# NCC_SAMPLE_ID
# MLS001246528              SRP01350r     46386546                RUTIN
# MLS001246538              SRP01485e     46386556      ESOMEPRAZOLE Mg
# MLS001246560              SRP00325i     46386578              ICARIIN
# MLS001246568              SRP01038v     46386586    VINDESINE SULFATE
# MLS001246570              SRP01037v     46386588  VINCRISTINE SULFATE
#
#               SUPPLIER_SAMPLE_COMMENTS SUPPLIER_SAMPLE_ID
# NCC_SAMPLE_ID
# MLS001246528                       NaN                NaN
# MLS001246538                       NaN                NaN
# MLS001246560                       NaN                NaN
# MLS001246568                       NaN                NaN
# MLS001246570                       NaN                NaN

# %%
bigDf.reset_index(level=0, inplace=True)

# %%
bigDf.head()
# Out:
#   NCC_SAMPLE_ID                                                ISM  \
# 0  MLS001246528  C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...
# 1  MLS001246538  COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...
# 2  MLS001246560  COc1ccc(cc1)c2oc3c(CC=C(C)C)c(O[C@@H]4O[C@H](C...
# 3  MLS001246568  CC[C@]1(O)C[C@H]2CN(C1)CCc3c([nH]c4ccccc34)[C@...
# 4  MLS001246570  CC[C@]1(O)C[C@@H]2CN(C1)CCc3c([nH]c4ccccc34)[C...
#
#   NCC_STRUCTURE_ID  STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 0     SMR000112560          C27H30O16            610.5274    610.5274
# 1     SMR000469280     C34H36MgN6O6S2            713.1236    713.1236
# 2     SMR000466309          C33H40O15            676.6740    676.6740
# 3     SMR000469153   C43H55N5O7.H2O4S            852.0208    753.9423
# 4     SMR000058540  C46H56N4O10.H2O4S            923.0533    824.9748
#
#    PARENT_EMW                 SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  \
# 0    610.1533  Sequoia Research Products Ltd.             SRP01350r
# 1    712.5187  Sequoia Research Products Ltd.             SRP01485e
# 2    676.2367  Sequoia Research Products Ltd.             SRP00325i
# 3    753.4101  Sequoia Research Products Ltd.             SRP01038v
# 4    824.3996  Sequoia Research Products Ltd.             SRP01037v
#
#    PUBCHEM_SID   STRUCTURE_SYNONYMS SUPPLIER_SAMPLE_COMMENTS  \
# 0     46386546                RUTIN                      NaN
# 1     46386556      ESOMEPRAZOLE Mg                      NaN
# 2     46386578              ICARIIN                      NaN
# 3     46386586    VINDESINE SULFATE                      NaN
# 4     46386588  VINCRISTINE SULFATE                      NaN
#
#   SUPPLIER_SAMPLE_ID
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
bigDf[["ISM","NCC_SAMPLE_ID"]]
# Out:
#                                                   ISM NCC_SAMPLE_ID
# 0   C[C@@H]1O[C@@H](OC[C@H]2O[C@@H](Oc3c(oc4cc(O)c...  MLS001246528
# 1   COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...  MLS001246538
# 2   COc1ccc(cc1)c2oc3c(CC=C(C)C)c(O[C@@H]4O[C@H](C...  MLS001246560
# 3   CC[C@]1(O)C[C@H]2CN(C1)CCc3c([nH]c4ccccc34)[C@...  MLS001246568
# 4   CC[C@]1(O)C[C@@H]2CN(C1)CCc3c([nH]c4ccccc34)[C...  MLS001246570
# 5   CCCc1nc(C)c2c(O)nc(nn12)c3cc(ccc3OCC)S(=O)(=O)...  MLS001246573
# 6   CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...  MLS001246578
# 7   CC(C)(C)NC(=O)[C@@H]1CN(Cc2cccnc2)CCN1C[C@@H](...  MLS001246588
# 8   CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c5=NC6(CCN(CC...  MLS001246589
# 9   CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c5nc6cc(C)ccn...  MLS001246597
# 10  CCc1c2Cn3c(cc4c(COC(=O)[C@]4(O)CC)c3=O)-c2nc5c...  MLS001246598
# 11  CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c(O)c(C=NN5CC...  MLS001246620
# 12  CCCCc1oc2ccccc2c1C(=O)c3cc(I)c(OCCN(CC)CC)c(I)...  MLS001246646
# 13  Cc1c(O)cccc1C(=O)N[C@@H](CSc2ccccc2)[C@H](O)CN...  MLS001246655
# 14  CC(C)(O)c1ccccc1CC[C@@H](SCC2(CC(=O)[O-])CC2)c...  MLS001246657
# 15  CO[C@@H]1C[C@@H](CC[C@H]1O)/C=C(\C)/[C@H]2OC(=...  MLS001246677
# 16  CCC(C)n1ncn(c2ccc(cc2)N3CCN(CC3)c4ccc(OCC5COC(...  MLS001246679
# 17  CC(=O)O[C@]12CO[C@@H]2C[C@H](O)[C@]3(C)[C@@H]1...  MLS001246689
# 18  CCOc1cc(N)c(Cl)cc1C(=O)NCC2CN(Cc3ccc(F)cc3)CCO...  MLS001246713
# 19  CO[C@H]1[C@@H](CC(=O)O[C@H](C)CC=CC=C[C@H](O)[...  MLS001246731
# 20  C[C@H]1O[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@@H](O...  MLS001246733
# 21  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...  MLS001246748
# 22  CCC1=C[C@H]2CN(C1)Cc3c([nH]c4ccccc34)[C@@](C2)...  MLS001246780
# 23  CC(C)[C@H](NC(=O)N(C)Cc1csc(n1)C(C)C)C(=O)N[C@...  MLS001246783
# 24  CC(C)CC(NC(=O)C(COC(C)(C)C)NC(=O)C(Cc1ccc(O)cc...  MLS001246784
# 25  COc1ccc(CC2c3cc(OC)c(OC)cc3CC[N+]2(C)CCC(=O)OC...  MLS001246793
# 26  O[C@H](C[C@H](O)/C=C/c1c(nc2ccccc2c1c3ccc(F)cc...  MLS001246803
# 27  CC[C@H]1OC(=O)[C@H](C)C(=O)[C@H](C)[C@@H](O[C@...  MLS001246805
# 28  CC(=O)O[C@H]1[C@H](C[C@H]2[C@@H]3CC[C@H]4C[C@H...  MLS001246821
# 29  CC(C)[C@H]1NC(=O)[C@@H](NC(=O)c2ccc(C)c3oc4c(C...  MLS001246846
# 30  CC(C)(O)[C@@H]1[C@H]2OC(=O)[C@@H]1[C@]3(O)C[C@...  MLS001246993
# 31  CC(=O)OC1C(C[C@H]2C3CC[C@H]4C[C@H](OC(=O)C)C(C...  MLS001247003
# 32  CN1CCN(CCCN2c3ccccc3Sc4ccc(Cl)cc24)CC1.OC(=O)/...  MLS001247054
# 33  CC(CCCCC(=O)Nc1ccc(cc1)C(F)(F)F)NCCc2c[nH]cn2....  MLS001247089
# 34  CO[C@H]1\C=C\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(NC(=...  MLS002264646
# 35  N[C@@H](Cc1cc(I)c(Oc2cc(I)c(O)c(I)c2)c(I)c1)C(...  MLS002264651
# 36         NC(Cc1cc(I)c(Oc2ccc(O)c(I)c2)c(I)c1)C(=O)O  MLS003107539
# 37  OCCOCCN1CCN(CC1)C(c2ccccc2)c3ccc(Cl)cc3.OC(=O)...  MLS002554902
# 38  C[C@H]1O[C@H](C[C@H](O)[C@@H]1O)O[C@H]2[C@@H](...  MLS002564205
# 39  CCOC(=O)CCC(=O)OC1C(CC(C)OC1OC2C(C)C(OC3CC(C)(...  MLS002564242
# 40  CO[C@H]1\C=C\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(NC(=...  MLS002589953
# 41  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...  MLS002589961
# 42  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C2=O)c4c5=NC6(CCN(...  MLS002589970

# %%
bigDf['STRUCTURE_REAL_AMW'].hist()

# %%
bigDf['STRUCTURE_REAL_AMW'].plot()
bigDf['STRUCTURE_REAL_AMW'].plot(c = 'r')

# %%
df['STRUCTURE_REAL_AMW'].plot()

# %%
df.sort_values('STRUCTURE_REAL_AMW')
# Out:
#     NCC_SAMPLE_ID                                                ISM  \
# 364  MLS001247014                                    N[C@@H]1CONC1=O
# 506  MLS002264599                                    N[C@@H]1CONC1=O
# 301  MLS001246894                                         OCc1cccnc1
# 367  MLS001247017                                       Oc1ncc(F)cn1
# 526  MLS002548951                                          Cn1ccnc1S
# 268  MLS001246860                                     NC(=O)c1cccnc1
# 274  MLS001246867                                        NCCc1ccccn1
# 568  MLS002554917                                     OC(=O)c1cccnc1
# 578  MLS002554927                                     NC(=O)c1cnccn1
# 278  MLS001246871                                     Cc1occc(=O)c1O
# 277  MLS001246870                                      OC(=O)C(Cl)Cl
# 209  MLS001246753                                      Nc1nc(O)ncc1F
# 452  MLS002264615                                    Oc1ncc(F)c(O)n1
# 645  MLS002589919                                    NCC(=O)CCC(=O)O
# 263  MLS001246854                                  Nc1ccc2c[nH]nc2c1
# 490  MLS002554884                                  Oc1[nH]cnc2nncc12
# 692  MLS002589985                                       NNCCc1ccccc1
# 557  MLS002554904                                    NNC(=O)c1ccncc1
# 365  MLS001247015                                  Cc1c(O)c(=O)ccn1C
# 624  MLS002564230                                    CCCC(CCC)C(=O)O
# 366  MLS001247016                             OC(=O)[C@@H]1CSC(=O)N1
# 375  MLS001247026                                  C1CNC(C1)c2cccnc2
# 473  MLS002264642                                 CC(C)(S)C(N)C(=O)O
# 657  MLS002589937                                  Sc1[nH]cnc2ncnc12
# 370  MLS001247020                               Nc1ccc(O)c(c1)C(=O)O
# 267  MLS001246858                                 C(c1ccccc1)n2ccnc2
# 618  MLS002564224                               CN1CCC[C@H]1c2cccnc2
# 309  MLS001246908                       [O-][N+](=O)c1cccc2c[nH]nc12
# 519  MLS002548937                             [O-]S(=O)(=O)CCS.[Na+]
# 466  MLS002264634                                  OC(=O)CCCc1ccccc1
# ..            ...                                                ...
# 113  MLS001246646  CCCCc1oc2ccccc2c1C(=O)c3cc(I)c(OCCN(CC)CC)c(I)...
# 144  MLS001246679  CCC(C)n1ncn(c2ccc(cc2)N3CCN(CC3)c4ccc(OCC5COC(...
# 58   MLS001246588  CC(C)(C)NC(=O)[C@@H]1CN(Cc2cccnc2)CCN1C[C@@H](...
# 12   MLS001246538  COc1ccc2n([Mg]n3c(nc4cc(OC)ccc34)S(=O)Cc5ncc(C...
# 236  MLS001246783  CC(C)[C@H](NC(=O)N(C)Cc1csc(n1)C(C)C)C(=O)N[C@...
# 354  MLS001247003  CC(=O)OC1C(C[C@H]2C3CC[C@H]4C[C@H](OC(=O)C)C(C...
# 204  MLS001246748  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# 675  MLS002589961  CC[C@H]1OC(=O)[C@H](C)[C@@H](O[C@H]2C[C@@](C)(...
# 555  MLS002554902  OCCOCCN1CCN(CC1)C(c2ccccc2)c3ccc(Cl)cc3.OC(=O)...
# 48   MLS001246578  CC(C)(C)NC(=O)[C@@H]1C[C@@H]2CCCC[C@@H]2CN1C[C...
# 482  MLS002264651  N[C@@H](Cc1cc(I)c(Oc2cc(I)c(O)c(I)c2)c(I)c1)C(...
# 600  MLS002564205  C[C@H]1O[C@H](C[C@H](O)[C@@H]1O)O[C@H]2[C@@H](...
# 67   MLS001246597  CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c5nc6cc(C)ccn...
# 142  MLS001246677  CO[C@@H]1C[C@@H](CC[C@H]1O)/C=C(\C)/[C@H]2OC(=...
# 153  MLS001246689  CC(=O)O[C@]12CO[C@@H]2C[C@H](O)[C@]3(C)[C@@H]1...
# 247  MLS001246805  CC[C@H]1OC(=O)[C@H](C)C(=O)[C@H](C)[C@@H](O[C@...
# 477  MLS002264646  CO[C@H]1\C=C\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(NC(=...
# 190  MLS001246731  CO[C@H]1[C@@H](CC(=O)O[C@H](C)CC=CC=C[C@H](O)[...
# 683  MLS002589970  CO[C@H]1/C=C/O[C@@]2(C)Oc3c(C2=O)c4c5=NC6(CCN(...
# 59   MLS001246589  CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c5=NC6(CCN(CC...
# 39   MLS001246568  CC[C@]1(O)C[C@H]2CN(C1)CCc3c([nH]c4ccccc34)[C@...
# 635  MLS002564242  CCOC(=O)CCC(=O)OC1C(CC(C)OC1OC2C(C)C(OC3CC(C)(...
# 668  MLS002589953  CO[C@H]1\C=C\O[C@@]2(C)Oc3c(C)c(O)c4c(O)c(NC(=...
# 88   MLS001246620  CO[C@H]1C=CO[C@@]2(C)Oc3c(C2=O)c4c(O)c(C=NN5CC...
# 245  MLS001246803  O[C@H](C[C@H](O)/C=C/c1c(nc2ccccc2c1c3ccc(F)cc...
# 40   MLS001246570  CC[C@]1(O)C[C@@H]2CN(C1)CCc3c([nH]c4ccccc34)[C...
# 234  MLS001246780  CCC1=C[C@H]2CN(C1)Cc3c([nH]c4ccccc34)[C@@](C2)...
# 240  MLS001246793  COc1ccc(CC2c3cc(OC)c(OC)cc3CC[N+]2(C)CCC(=O)OC...
# 259  MLS001246846  CC(C)[C@H]1NC(=O)[C@@H](NC(=O)c2ccc(C)c3oc4c(C...
# 237  MLS001246784  CC(C)CC(NC(=O)C(COC(C)(C)C)NC(=O)C(Cc1ccc(O)cc...
#
#     NCC_STRUCTURE_ID       STRUCTURE_REAL_MF  STRUCTURE_REAL_AMW  PARENT_AMW  \
# 364     SMR000058313                C3H6N2O2            102.0932    102.0932
# 506     SMR000058313                C3H6N2O2            102.0932    102.0932
# 301     SMR000059086                  C6H7NO            109.1281    109.1281
# 367     SMR000449315                C4H3FN2O            114.0792    114.0792
# 526     SMR000058376                 C4H6N2S            114.1654    114.1654
# 268     SMR000058212                 C6H6N2O            122.1268    122.1268
# 274     SMR000059100                 C7H10N2            122.1704    122.1704
# 568     SMR000059024                 C6H5NO2            123.1115    123.1115
# 578     SMR000036662                 C5H5N3O            123.1145    123.1145
# 278     SMR000059093                  C6H6O3            126.1122    126.1122
# 277     SMR000059158               C2H2Cl2O2            128.9428    128.9428
# 209     SMR000059047                C4H4FN3O            129.0939    129.0939
# 452     SMR000038082               C4H3FN2O2            130.0786    130.0786
# 645     SMR000857229                 C5H9NO3            131.1319    131.1319
# 263     SMR000059077                  C7H7N3            133.1531    133.1531
# 490     SMR000059083                 C5H4N4O            136.1132    136.1132
# 692     SMR001496977                 C8H12N2            136.1974    136.1974
# 557     SMR000059082                 C6H7N3O            137.1415    137.1415
# 365     SMR000059136                 C7H9NO2            139.1545    139.1545
# 624     SMR000499581                 C8H16O2            144.2148    144.2148
# 366     SMR000449326                C4H5NO3S            147.1489    147.1489
# 375     SMR000449277                 C9H12N2            148.2084    148.2084
# 473     SMR000059161               C5H11NO2S            149.2085    149.2085
# 657     SMR000544948                 C5H4N4S            152.1738    152.1738
# 370     SMR000145728                 C7H7NO3            153.1379    153.1379
# 267     SMR000059044                C10H10N2            158.2034    158.2034
# 618     SMR000059074                C10H14N2            162.2354    162.2354
# 309     SMR000058266                C7H5N3O2            163.1359    163.1359
# 519     SMR000059219            C2H5O3S2.Na+            164.1700    141.1802
# 466     SMR000059104                C10H12O2            164.2048    164.2048
# ..               ...                     ...                 ...         ...
# 113     SMR000058296         C25H29I2NO3.HCl            681.7818    645.3209
# 144     SMR000058959           C35H38Cl2N8O4            705.6462    705.6462
# 58      SMR000469161        C36H47N5O4.H2O4S            711.8816    613.8031
# 12      SMR000469280          C34H36MgN6O6S2            713.1236    713.1236
# 236     SMR000466395            C37H48N6O5S2            720.9482    720.9482
# 354     SMR000466270         C35H60N2O4.2Br-            732.6840    572.8760
# 204     SMR000466382              C38H69NO13            747.9689    747.9689
# 675     SMR000471864             C38H72N2O12            749.0002    749.0002
# 555     SMR001370751  C21H27ClN2O2.C23H15O6-            762.2742    374.9122
# 48      SMR000469290       C38H50N6O5.CH4O3S            766.9609    670.8552
# 482     SMR000059176             C15H11I4NO4            776.8753    776.8753
# 600     SMR001906774               C41H64O14            780.9384    780.9384
# 67      SMR000466324             C43H51N3O11            785.8945    785.8945
# 142     SMR000466356              C44H69NO12            804.0355    804.0355
# 153     SMR000059010              C43H53NO14            807.8953    807.8953
# 247     SMR000469222             C43H65N5O10            812.0205    812.0205
# 477     SMR001906767             C43H58N4O12            822.9402    822.9402
# 190     SMR000469235              C42H69NO15            828.0117    828.0117
# 683     SMR001227203             C46H62N4O11            847.0222    847.0222
# 59      SMR000466322             C46H62N4O11            847.0222    847.0222
# 39      SMR000469153        C43H55N5O7.H2O4S            852.0208    753.9423
# 635     SMR001491659              C43H75NO16            862.0701    862.0701
# 668     SMR001906779             C47H64N4O12            877.0306    877.0306
# 88      SMR000466332             C47H64N4O12            877.0486    877.0486
# 245     SMR000469287          C50H46CaF2N2O8            881.0035    881.0035
# 40      SMR000058540       C46H56N4O10.H2O4S            923.0533    824.9748
# 234     SMR000469210      C45H54N4O8.2C4H6O6           1079.1258    778.9490
# 240     SMR000471626    C53H72N2O12.2C6H5O3S           1243.4936    929.1652
# 259     SMR000469227            C62H86N12O16           1255.4408   1255.4408
# 237     SMR000469214     C59H84N18O14.C2H4O2           1329.4852   1269.4332
#
#      PARENT_EMW                 SAMPLE_SUPPLIER SUPPLIER_STRUCTURE_ID  \
# 364    102.0429               Tocris Bioscience                101840
# 506    102.0429                LightBiologicals                C-3119
# 301    109.0527          Sigma Chemical Company                P66807
# 367    114.0229               Tocris Bioscience                101322
# 526    114.0251                         Enamine              39532476
# 268    122.0480          Sigma Chemical Company                240206
# 274    122.0843          Sigma Chemical Company                A55306
# 568    123.0320                LightBiologicals                N-9547
# 578    123.0432                LightBiologicals                P-9640
# 278    126.0316          Sigma Chemical Company                H43407
# 277    127.9431          Sigma Chemical Company                D54702
# 209    129.0338  Sequoia Research Products Ltd.             SRP01027f
# 452    130.0178                LightBiologicals                 F-599
# 645    131.0582                LightBiologicals                O-3937
# 263    133.0639          Sigma Chemical Company                A59565
# 490    136.0385                LightBiologicals                A-6331
# 692    136.1000                LightBiologicals                P-7767
# 557    137.0589                LightBiologicals                I-0066
# 365    139.0633               Tocris Bioscience                101427
# 624    144.1150                LightBiologicals                P-6059
# 366    146.9990               Tocris Bioscience                101743
# 375    148.1000               Tocris Bioscience                100188
# 473    149.0510                LightBiologicals                P-8548
# 657    152.0156                LightBiologicals                M-8526
# 370    153.0425               Tocris Bioscience                101661
# 267    158.0843          Sigma Chemical Company                116416
# 618    162.1156                LightBiologicals                N-3255
# 309    163.0381          Sigma Chemical Company                 N7778
# 519    140.9680                         Enamine             241392125
# 466    164.0837                LightBiologicals                P-3345
# ..          ...                             ...                   ...
# 113    645.0237  Sequoia Research Products Ltd.             SRP05610a
# 144    704.2393  Sequoia Research Products Ltd.             SRP02500i
# 58     613.3628  Sequoia Research Products Ltd.             SRP00675i
# 12     712.5187  Sequoia Research Products Ltd.             SRP01485e
# 236    720.3127  Sequoia Research Products Ltd.             SRP01303r
# 354    572.4553               Tocris Bioscience                100349
# 204    747.4768  Sequoia Research Products Ltd.             SRP03660c
# 675    748.5085                LightBiologicals                A-5199
# 555    374.1761                LightBiologicals                H-3432
# 48     670.3842  Sequoia Research Products Ltd.             SRP01070s
# 482    776.6868                LightBiologicals                T-9065
# 600    780.4296                LightBiologicals                D-6339
# 67     785.3523  Sequoia Research Products Ltd.             SRP01281r
# 142    803.4819  Sequoia Research Products Ltd.             SRP00750t
# 153    807.3466  Sequoia Research Products Ltd.             SRP04571d
# 247    811.4731  Sequoia Research Products Ltd.             SRP01191t
# 477    822.4051                LightBiologicals                R-5160
# 190    827.4667  Sequoia Research Products Ltd.             SRP01340k
# 683    846.4415                LightBiologicals                R-3035
# 59     846.4415  Sequoia Research Products Ltd.             SRP01275r
# 39     753.4101  Sequoia Research Products Ltd.             SRP01038v
# 635    861.5085                LightBiologicals                E-8801
# 668    876.4520                LightBiologicals                R-1119
# 88     876.4520  Sequoia Research Products Ltd.             SRP01280r
# 245    880.4022  Sequoia Research Products Ltd.             SRP02390i
# 40     824.3996  Sequoia Research Products Ltd.             SRP01037v
# 234    778.3941  Sequoia Research Products Ltd.             SRP01040v
# 240    928.5085  Sequoia Research Products Ltd.             SRP07340a
# 259   1254.6284  Sequoia Research Products Ltd.             SRP00450d
# 237   1268.6414  Sequoia Research Products Ltd.             SRP02570g
#
#      PUBCHEM_SID                                 STRUCTURE_SYNONYMS  \
# 364     46386864                             D-CYCLOSERINE, 68-41-7
# 506    104170174                             D-CYCLOSERINE, 68-41-7
# 301     46386968                       3-PYRIDINEMETHANOL, 100-55-0
# 367     46386867                              5-fluoro-2-pyrimidone
# 526    104170134                               Methimazole, 60-56-0
# 268     46386893                              NICOTINAMIDE, 98-92-0
# 274     46386941                           2-(2-AMINOETHYL)PYRIDINE
# 568    104170022                            Nicotinic Acid, 59-67-6
# 578    104170032                                           98-96-4,
# 278     46386945              3-Hydroxy-2-methyl-4-pyrone, 118-71-8
# 277     46386944                       DICHLOROACETIC ACID, 79-43-6
# 209     46386766                                   5-FLUOROCYTOSINE
# 452    104169952                            5-FLUOROURACIL, 51-21-8
# 645    104170099                      Aminolevulinic Acid, 9/2/5451
# 263     46386887                                    6-AMINOINDAZOLE
# 490    104169990                                                  ,
# 692    104170190                               Phenelzine, 156-51-4
# 557    104170011                                 Isoniazid, 54-85-3
# 365     46386865              3-HYDROXY-1,2-DIMETHYL-4(1H)-PYRIDONE
# 624    104170082                                           99-66-1,
# 366     46386866  4-Thiazolidinecarboxylic acid, 2-oxo-, (R)- [C...
# 375     46386896                                        Nornicotine
# 473    104169974                          DL-PENICILLAMINE, 52-66-4
# 657    104170111                                    Mercaptopurine,
# 370     46386870            5-Amino-2-hydroxy-benzoic acid, 89-57-6
# 267     46386891                                  1-BENZYLIMIDAZOLE
# 618    104170075                                  NICOTINE, 54-11-5
# 309     46387020                                    7-NITROINDAZOLE
# 519    104170146                                                  ,
# 466    104169967                                         1716-12-7,
# ..           ...                                                ...
# 113     46386662               AMIODARONE HYDROCHLORIDE, 19774-82-4
# 144     46386736                                       ITRACONAZOLE
# 58      46386606                    INDINAVIR SULPHATE, 157810-81-6
# 12      46386556                                    ESOMEPRAZOLE Mg
# 236     46386817                                          RITONAVIR
# 354     46386853                                        Pancuronium
# 204     46386761                                     CLARITHROMYCIN
# 675    104170210                                      Azithromycin,
# 555    104170009                       Vistaril Pamoate, 10246-75-0
# 48      46386596                                SAQUINAVIR MESYLATE
# 482    104169983                                       L-THYROXINE,
# 600    104170057                                           DIGOXIN,
# 67      46386615                                          RIFAXIMIN
# 142     46386734                                         TACROLIMUS
# 153     46386672                                          DOCETAXEL
# 247     46386829                                      TELITHROMYCIN
# 477    104169978                                        RIFAMPICIN,
# 190     46386711                                        KITASAMYCIN
# 683    104170218                              Rifabutin, 72559-06-9
# 59      46386607                                          RIFABUTIN
# 39      46386586                                  VINDESINE SULFATE
# 635    104170095                                  Eryped, 1264-62-6
# 668    104170198                                       RIFAPENTINE,
# 88      46386637                                        RIFAPENTINE
# 245     46386827                                     ITAVASTATIN Ca
# 40      46386588                                VINCRISTINE SULFATE
# 234     46386815                              VINORELBINE BITATRATE
# 240     46386822                                ATRACURIUM BESYLATE
# 259     46386883                                       DACTINOMYCIN
# 237     46386818                                  GOSERELIN ACETATE
#
#            SUPPLIER_SAMPLE_COMMENTS SUPPLIER_SAMPLE_ID
# 364                             NaN                NaN
# 506                               .                  .
# 301                             NaN                NaN
# 367                             NaN                NaN
# 526                               .                  .
# 268                             NaN                NaN
# 274                             NaN                NaN
# 568                    WHITE POWDER                  .
# 578                    WHITE POWDER                  .
# 278                             NaN                NaN
# 277                             NaN                NaN
# 209                             NaN                NaN
# 452                               .                  .
# 645  WHITE FINE CRYSTALS WITH LUMPS                  .
# 263                             NaN                NaN
# 490                OFF WHITE POWDER                  .
# 692       WHITE TO OFF-WHITE POWDER                  .
# 557                    WHITE POWDER                  .
# 365                             NaN                NaN
# 624                    CLEAR LIQUID                  .
# 366                             NaN                NaN
# 375                             NaN                NaN
# 473                               .                  .
# 657                   YELLOW POWDER                  .
# 370                             NaN                NaN
# 267                             NaN                NaN
# 618  FAINTLY BROWNISH-YELLOW LIQUID                  .
# 309                             NaN                NaN
# 519                               .                  .
# 466                               .                  .
# ..                              ...                ...
# 113                             NaN                NaN
# 144                             NaN                NaN
# 58                              NaN                NaN
# 12                              NaN                NaN
# 236                             NaN                NaN
# 354                             NaN                NaN
# 204                             NaN                NaN
# 675           LIGHT-YELLOW CRYSTALS                  .
# 555             YELLOW-GREEN POWDER                  .
# 48                              NaN                NaN
# 482                               .                  .
# 600                    WHITE POWDER                  .
# 67                              NaN                NaN
# 142                             NaN                NaN
# 153                             NaN                NaN
# 247                             NaN                NaN
# 477                               .                  .
# 190                             NaN                NaN
# 683   PURPLE-RED CRYSTALLINE POWDER                  .
# 59                              NaN                NaN
# 39                              NaN                NaN
# 635                    WHITE POWDER                  .
# 668     DARK-RED CRYSTALLINE POWDER                  .
# 88                              NaN                NaN
# 245                             NaN                NaN
# 40                              NaN                NaN
# 234                             NaN                NaN
# 240                             NaN                NaN
# 259                             NaN                NaN
# 237                             NaN                NaN
#
# [726 rows x 13 columns]

# %%
newDf = df.sort_values('STRUCTURE_REAL_AMW')

# %%
newDf.head()
# Out:
#     NCC_SAMPLE_ID              ISM NCC_STRUCTURE_ID STRUCTURE_REAL_MF  \
# 364  MLS001247014  N[C@@H]1CONC1=O     SMR000058313          C3H6N2O2
# 506  MLS002264599  N[C@@H]1CONC1=O     SMR000058313          C3H6N2O2
# 301  MLS001246894       OCc1cccnc1     SMR000059086            C6H7NO
# 367  MLS001247017     Oc1ncc(F)cn1     SMR000449315          C4H3FN2O
# 526  MLS002548951        Cn1ccnc1S     SMR000058376           C4H6N2S
#
#      STRUCTURE_REAL_AMW  PARENT_AMW  PARENT_EMW         SAMPLE_SUPPLIER  \
# 364            102.0932    102.0932    102.0429       Tocris Bioscience
# 506            102.0932    102.0932    102.0429        LightBiologicals
# 301            109.1281    109.1281    109.0527  Sigma Chemical Company
# 367            114.0792    114.0792    114.0229       Tocris Bioscience
# 526            114.1654    114.1654    114.0251                 Enamine
#
#     SUPPLIER_STRUCTURE_ID  PUBCHEM_SID            STRUCTURE_SYNONYMS  \
# 364                101840     46386864        D-CYCLOSERINE, 68-41-7
# 506                C-3119    104170174        D-CYCLOSERINE, 68-41-7
# 301                P66807     46386968  3-PYRIDINEMETHANOL, 100-55-0
# 367                101322     46386867         5-fluoro-2-pyrimidone
# 526              39532476    104170134          Methimazole, 60-56-0
#
#     SUPPLIER_SAMPLE_COMMENTS SUPPLIER_SAMPLE_ID
# 364                      NaN                NaN
# 506                        .                  .
# 301                      NaN                NaN
# 367                      NaN                NaN
# 526                        .                  .

# %%
newDf = newDf.reindex
newDf.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-787c12639934> in <module>()
#       1 newDf = newDf.reindex
# ----> 2 newDf.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
df['STRUCTURE_REAL_AMW'].hist()

# %%
FDA_FileName = 'L1300-Selleck-FDA-Approved-Drug-Library-1018cpds.xlsx'

# %%
xl_FDA = pd.ExcelFile(FDA_FileName)

# %%
xl_FDA.sheet_names

# %%
dfFDA = xl_FDA.parse('Chemical Data-1018cpds')

# %%
dfFDA[dfFDA.Smiles == "Cc1cn([C@@H]2O[C@H](CO)C=C2)c(=O)[nH]c1=O"]

# %%
dfFDA.head()

# %% [markdown]
# Identfy overlaps between these two libraries, utilizing smiles as a key.

# %%
counter = 0
for item in df.ISM:
    if not dfFDA[dfFDA.Smiles == item].empty :
        print (dfFDA[dfFDA.Smiles == item])
        print (item)
        counter +=1
print (counter)
